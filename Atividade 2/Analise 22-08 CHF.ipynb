# %% [markdown]
# ### Objetivo: Consumir API - ETL BCB
#
# Acessando a url https://dadosabertos.bcb.gov.br/dataset/estatisticas-meios-pagamentos tive acesso aos dados fornecidos pelo banco central sobre meios de pagamentos.
# Vocês também pode consultar a API para obter a url para requisição dos dados.
#
# ### Primeira Etapa: Cotação do Dólar por período

# %% [markdown]
# Vamos pegar a url, configurada pelos recursos (https://olinda.bcb.gov.br/olinda/servico/PTAX/versao/v1/aplicacao#!/recursos), focamos no Câmbio então, a cotação por período e por data específica.

# %%
url = "https://olinda.bcb.gov.br/olinda/servico/PTAX/versao/v1/odata/CotacaoMoedaPeriodo(moeda=@moeda,dataInicial=@dataInicial,dataFinalCotacao=@dataFinalCotacao)?@moeda='CHF'&@dataInicial='01-01-2023'&@dataFinalCotacao='07-31-0025'&$top=100&$format=json&$select=paridadeCompra,paridadeVenda,cotacaoCompra,cotacaoVenda,dataHoraCotacao,tipoBoletim"

# %% [markdown]
# E então chamar a função principal

# %%
import pandas as pd
import requests
import json

# %% [markdown]
# Agora vamos nas bibliotecas

# %%
def requisicao_api(link):
  resposta = requests.get(link)

  if resposta.status_code == 200:
    dados = resposta.json()
    print('Status Code:', resposta.status_code)
    with open('resultado.json', 'w', encoding='utf-8') as arquivo:
      json.dump(dados, arquivo, ensure_ascii=False, indent=4)

  else:
    print('Status Code:', resposta.status_code)

# %% [markdown]
# Definir a requisição para a url

# %%
requisicao_api(url)
# Out:
# Status Code: 200

# %% [markdown]
# Configurar o JSON para ser lido

# %%
jsondata = pd.read_json('resultado.json')

# %% [markdown]
# Ler os dados no JSON

# %%
jsondata
# Out:
#                                        @odata.context  \
# 0   https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 1   https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 2   https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 3   https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 4   https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# ..                                                ...
# 95  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 96  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 97  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 98  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 99  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
#
#                                                 value
# 0   {'cotacaoCompra': 5.343, 'cotacaoVenda': 5.343...
# 1   {'cotacaoCompra': 5.3753, 'cotacaoVenda': 5.37...
# 2   {'cotacaoCompra': 5.4453, 'cotacaoVenda': 5.44...
# 3   {'cotacaoCompra': 5.402, 'cotacaoVenda': 5.402...
# 4   {'cotacaoCompra': 5.2849, 'cotacaoVenda': 5.28...
# ..                                                ...
# 95  {'cotacaoCompra': 4.9674, 'cotacaoVenda': 4.96...
# 96  {'cotacaoCompra': 4.9668, 'cotacaoVenda': 4.96...
# 97  {'cotacaoCompra': 4.9468, 'cotacaoVenda': 4.94...
# 98  {'cotacaoCompra': 4.9984, 'cotacaoVenda': 4.99...
# 99  {'cotacaoCompra': 5.0108, 'cotacaoVenda': 5.01...
#
# [100 rows x 2 columns]

# %% [markdown]
# Adicionar o valor para o data

# %%
data = jsondata['value']

# %% [markdown]
# E agora formatar utilizando o normalize para as datas

# %%
dados_df = pd.json_normalize(data)

# %% [markdown]
# Por último, formatar em cabeçalhos de até 100 itens

# %%
dados_df.head(100)
# Out:
#     cotacaoCompra  cotacaoVenda          dataHoraCotacao
# 0          5.3430        5.3436  2023-01-02 13:05:57.593
# 1          5.3753        5.3759   2023-01-03 13:11:19.08
# 2          5.4453        5.4459  2023-01-04 13:09:19.572
# 3          5.4020        5.4026  2023-01-05 13:03:32.262
# 4          5.2849        5.2855  2023-01-06 13:02:28.727
# ..            ...           ...                      ...
# 95         4.9674        4.9680  2023-05-22 13:05:22.716
# 96         4.9668        4.9674  2023-05-23 13:08:23.321
# 97         4.9468        4.9474  2023-05-24 13:04:35.737
# 98         4.9984        4.9990  2023-05-25 13:04:36.531
# 99         5.0108        5.0114   2023-05-26 13:07:17.73
#
# [100 rows x 3 columns]
